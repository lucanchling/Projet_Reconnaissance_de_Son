# %%
import scipy.io.wavfile as wavfile
import scipy.fftpack as fftpack
import numpy as np
import matplotlib.pyplot as plt
from pydub import AudioSegment
# Out:
# c:\Users\emmao\AppData\Local\Programs\Python\Python37\lib\site-packages\pydub\utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)

# %%
choix_music="1"

# %%
#s_rate, signal = wavfile.read('./music/music1.wav')
sound = AudioSegment.from_wav('./music/music'+str(choix_music)+'.wav')
sound = sound.set_channels(1)
sound.export('./music/music'+str(choix_music)+'_mono.wav', format='wav')

s_rate, signal = wavfile.read('./music/music'+str(choix_music)+'_mono.wav')
#signal = signal.astype('uint16')

#s = signal[:,0]
#création instants d'échantillons 
t = np.linspace(0, signal.shape[0]/s_rate, signal.shape[0])

#tracé du signal 
plt.plot(t,signal)

# %%
FFT = fftpack.fft(signal)
freq = fftpack.fftfreq(signal.size,d=1/s_rate)

#calcul du nombre d'échantillon 
N = signal.size
FFT_abs = np.abs(FFT[:N//2])*2.0/N
freq_pos = freq[:N//2]

plt.figure(figsize=(8,8))
plt.plot(freq_pos, FFT_abs)
plt.show()

# %%
for i,v in enumerate(signal):
    if v!=0:
        indice = i
        break
print(i)

plt.specgram(signal[25:400],NFFT=256,Fs=1/s_rate,noverlap=128)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15644\3710491190.py in <module>
# ----> 1 k = string.find(signal!=0)
#       2
#       3 plt.specgram(signal[25:400],NFFT=256,Fs=1/s_rate,noverlap=128)
#
# NameError: name 'string' is not defined
